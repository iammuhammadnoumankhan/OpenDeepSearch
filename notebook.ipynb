# %%
from opendeepsearch import OpenDeepSearchTool
import os

# %%
SERPER_API_KEY = os.getenv("SERPER_API_KEY")
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
JINA_API_KEY = os.getenv("JINA_API_KEY")
DEFAULT_MODEL = "openrouter/google/gemini-2.0-flash-001"
# CURRENT_DATE = datetime.now().strftime("%B %d, %Y")

# %%
# Using Serper (default)
search_agent = OpenDeepSearchTool(
    model_name="openrouter/google/gemini-2.0-flash-001",
    reranker="jina"
)

# %%
if not search_agent.is_initialized:
    search_agent.setup()
# Out:
# Using Jina Reranker

# %%
query = "Fastest land animal?"
result = search_agent.forward(query)
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-4' coro=<Connection.run() done, defined at c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\playwright\_impl\_connection.py:272> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\tasks.py", line 314, in __step_run_and_handle_result
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\playwright\_impl\_connection.py", line 279, in run
#     await self._transport.connect()
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\playwright\_impl\_transport.py", line 133, in connect
#     raise exc
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\playwright\_impl\_transport.py", line 120, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\base_events.py", line 1743, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\base_events.py", line 524, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# Error in process_sources: No module named 'src'
# 2025-04-07 16:04:26.833 | ERROR    | opendeepsearch.context_building.build_context:build_context:93 - An error occurred while building context: 'SearchResult' object has no attribute 'get'
# Traceback (most recent call last):
#
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\opendeepsearch\context_building\process_sources_pro.py", line 60, in process_sources
#     html_contents = await self._fetch_html_contents([s[1]['link'] for s in valid_sources])
#                           │    │                                           └ [(0, {'title': 'Fastest animals - Wikipedia', 'link': 'https://en.wikipedia.org/wiki/Fastest_animals', 'snippet': 'Land, Fast...
#                           │    └ <function SourceProcessor._fetch_html_contents at 0x0000013061A82520>
#                           └ <opendeepsearch.context_building.process_sources_pro.SourceProcessor object at 0x000001306862FE60>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\opendeepsearch\context_building\process_sources_pro.py", line 70, in _fetch_html_contents
#     raw_contents = await self.scraper.scrape_many(links)
#                          │    │       │           └ ['https://en.wikipedia.org/wiki/Fastest_animals', 'https://www.britannica.com/list/the-fastest-animals-on-earth']
#                          │    │       └ <function WebScraper.scrape_many at 0x0000013058D93EC0>
#                          │    └ <opendeepsearch.context_scraping.crawl4ai_scraper.WebScraper object at 0x00000130685EC4D0>
#                          └ <opendeepsearch.context_building.process_sources_pro.SourceProcessor object at 0x000001306862FE60>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\opendeepsearch\context_scraping\crawl4ai_scraper.py", line 115, in scrape_many
#     results_list = await asyncio.gather(*tasks)
#                          │       │       └ [<coroutine object WebScraper.scrape at 0x00000130688742A0>, <coroutine object WebScraper.scrape at 0x00000130688743D0>]
#                          │       └ <function gather at 0x000001304439FA60>
#                          └ <module 'asyncio' from 'c:\\Users\\iammu\\anaconda3\\envs\\base_env\\Lib\\asyncio\\__init__.py'>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\tasks.py", line 385, in __wakeup
#     future.result()
#     │      └ <method 'result' of '_asyncio.Future' objects>
#     └ <_GatheringFuture finished exception=ModuleNotFoundError("No module named 'src'")>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\tasks.py", line 314, in __step_run_and_handle_result
#     result = coro.send(None)
#              │    └ <method 'send' of 'coroutine' objects>
#              └ <coroutine object WebScraper.scrape at 0x00000130688742A0>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\opendeepsearch\context_scraping\crawl4ai_scraper.py", line 74, in scrape
#     from src.opendeepsearch.context_scraping.utils import get_wikipedia_content
#
# ModuleNotFoundError: No module named 'src'
#
#
# During handling of the above exception, another exception occurred:
#
#
# Traceback (most recent call last):
#
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from 'c:\\Users\\iammu\\anaconda3\\envs\\base_env\\Lib\\site-packages\\ipykernel\\kernelapp.py'>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x0000013046019BC0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x0000013041D47CB0>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x000001304601AD40>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x000001304604DCD0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x0000013041D47CB0>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function _patch_loop.<locals>.run_forever at 0x0000013068857BA0>
#     │    └ <_WindowsSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x000001304604DCD0>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#     │    └ <function _patch_loop.<locals>._run_once at 0x0000013068857CE0>
#     └ <_WindowsSelectorEventLoop running=True closed=False debug=False>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x0000013042B99260>
#     └ <Handle Task.task_wakeup(<Future finis...2B)>, ...],))>)>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle Task.task_wakeup(<Future finis...2B)>, ...],))>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle Task.task_wakeup(<Future finis...2B)>, ...],))>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle Task.task_wakeup(<Future finis...2B)>, ...],))>)>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#           │    └ <function Kernel.process_one at 0x0000013045FE6FC0>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x000001304604D730>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#           │         └ ([<zmq.Frame(b'9ee88c48-b78'...36B)>, <zmq.Frame(b'<IDS|MSG>')>, <zmq.Frame(b'df4e19530dbf'...64B)>, <zmq.Frame(b'{"date":"20...
#           └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x000001304604D730>>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#           └ <coroutine object IPythonKernel.execute_request at 0x00000130477AE740>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#                                   │       │      └ {'header': {'date': datetime.datetime(2025, 4, 7, 11, 4, 24, 987000, tzinfo=tzutc()), 'msg_id': 'fd7e90f1-7956-46f2-80c2-53b5...
#                                   │       └ [b'9ee88c48-b78c-4413-b35f-0b9a1825b992']
#                                   └ <zmq.eventloop.zmqstream.ZMQStream object at 0x000001304604E690>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x0000013045FA1540>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x0000013046012CA0>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000130477CEDB0>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': 'vscode-notebook-cell:/d%3A/DEVELOPMENT/FYP/FINAL-FYP/DEV/services/DeepRe...
#                              └ ('query = "Fastest land animal?"\nresult = search_agent.forward(query)',)
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x00000130455AE480>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000130477CEDB0>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              │      └ <coroutine object InteractiveShell.run_cell_async at 0x0000013045FBAF20>
#              └ <function _pseudo_sync_runner at 0x00000130455A1620>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x0000013045FBAF20>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ 'C:\\Users\\iammu\\AppData\\Local\\Temp\\ipykernel_17028\\1537396199.py'
#                        │    │             │        └ [<ast.Assign object at 0x0000013067888DD0>, <ast.Assign object at 0x0000013068CE8750>]
#                        │    │             └ <ast.Module object at 0x0000013068410290>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x00000130455AE7A0>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000130477CEDB0>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 130688789b0, execution_count=5 error_before_exec=None error_in_exec=None info=<ExecutionInfo objec...
#              │    │        └ <code object <module> at 0x0000013047625020, file "C:\Users\iammu\AppData\Local\Temp\ipykernel_17028\1537396199.py", line 1>
#              │    └ <function InteractiveShell.run_code at 0x00000130455AE840>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000130477CEDB0>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000130477CEDB0>
#          │         │    └ <property object at 0x0000013045599C10>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000130477CEDB0>
#          └ <code object <module> at 0x0000013047625020, file "C:\Users\iammu\AppData\Local\Temp\ipykernel_17028\1537396199.py", line 1>
#
#   File "C:\Users\iammu\AppData\Local\Temp\ipykernel_17028\1537396199.py", line 2, in <module>
#     result = search_agent.forward(query)
#              │            │       └ 'Fastest land animal?'
#              │            └ <function OpenDeepSearchTool.forward at 0x00000130688577E0>
#              └ <opendeepsearch.ods_tool.OpenDeepSearchTool object at 0x00000130683EE3C0>
#
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\opendeepsearch\ods_tool.py", line 35, in forward
#     answer = self.search_tool.ask_sync(query, max_sources=2, pro_mode=True)
#              │    │           │        └ 'Fastest land animal?'
#              │    │           └ <function OpenDeepSearchAgent.ask_sync at 0x0000013068857560>
#              │    └ <opendeepsearch.ods_agent.OpenDeepSearchAgent object at 0x0000013068719340>
#              └ <opendeepsearch.ods_tool.OpenDeepSearchTool object at 0x00000130683EE3C0>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\opendeepsearch\ods_agent.py", line 179, in ask_sync
#     return loop.run_until_complete(self.ask(query, max_sources, pro_mode))
#            │    │                  │    │   │      │            └ True
#            │    │                  │    │   │      └ 2
#            │    │                  │    │   └ 'Fastest land animal?'
#            │    │                  │    └ <function OpenDeepSearchAgent.ask at 0x00000130688574C0>
#            │    │                  └ <opendeepsearch.ods_agent.OpenDeepSearchAgent object at 0x0000013068719340>
#            │    └ <function _patch_loop.<locals>.run_until_complete at 0x0000013068857C40>
#            └ <_WindowsSelectorEventLoop running=True closed=False debug=False>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\nest_asyncio.py", line 92, in run_until_complete
#     self._run_once()
#     │    └ <function _patch_loop.<locals>._run_once at 0x0000013068857CE0>
#     └ <_WindowsSelectorEventLoop running=True closed=False debug=False>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\nest_asyncio.py", line 133, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x0000013042B99260>
#     └ <Handle Task.__wakeup(<_GatheringFu...named 'src'")>)>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle Task.__wakeup(<_GatheringFu...named 'src'")>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle Task.__wakeup(<_GatheringFu...named 'src'")>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle Task.__wakeup(<_GatheringFu...named 'src'")>)>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\tasks.py", line 388, in __wakeup
#     self.__step(exc)
#     │           └ ModuleNotFoundError("No module named 'src'")
#     └ <Task pending name='Task-1' coro=<OpenDeepSearchAgent.ask() running at c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packag...
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\tasks.py", line 303, in __step
#     self.__step_run_and_handle_result(exc)
#     │                                 └ ModuleNotFoundError("No module named 'src'")
#     └ <Task pending name='Task-1' coro=<OpenDeepSearchAgent.ask() running at c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packag...
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\asyncio\tasks.py", line 316, in __step_run_and_handle_result
#     result = coro.throw(exc)
#              │    │     └ ModuleNotFoundError("No module named 'src'")
#              │    └ <method 'throw' of 'coroutine' objects>
#              └ <coroutine object OpenDeepSearchAgent.ask at 0x0000013068793450>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\opendeepsearch\ods_agent.py", line 143, in ask
#     context = await self.search_and_build_context(query, max_sources, pro_mode)
#                     │    │                        │      │            └ True
#                     │    │                        │      └ 2
#                     │    │                        └ 'Fastest land animal?'
#                     │    └ <function OpenDeepSearchAgent.search_and_build_context at 0x0000013068857420>
#                     └ <opendeepsearch.ods_agent.OpenDeepSearchAgent object at 0x0000013068719340>
#   File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\opendeepsearch\ods_agent.py", line 118, in search_and_build_context
#     return build_context(processed_sources)
#            │             └ <opendeepsearch.serp_search.serp_search.SearchResult object at 0x00000130688780B0>
#            └ <function build_context at 0x0000013061AE84A0>
# > File "c:\Users\iammu\anaconda3\envs\base_env\Lib\site-packages\opendeepsearch\context_building\build_context.py", line 63, in build_context
#     organic_results = extract_information(sources_result.get('organic', []))
#                       │                   └ <opendeepsearch.serp_search.serp_search.SearchResult object at 0x00000130688780B0>
#                       └ <function extract_information at 0x0000013061A827A0>
#
# AttributeError: 'SearchResult' object has no attribute 'get'

# %%
print(result)
